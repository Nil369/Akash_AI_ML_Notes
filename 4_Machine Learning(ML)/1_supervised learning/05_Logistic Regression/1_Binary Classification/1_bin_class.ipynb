# %% [markdown]
# ***The below problem is a binary logistic regression problem as there are only two possible outcomes (i.e. if person buys insurance or he/she doesn't).***

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("insurance_data.csv")
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
plt.figure(figsize=(6,3))
plt.scatter(df.age,df.bought_insurance,marker="+",color="red")
plt.xlabel("age")
plt.ylabel("bought_incurance")
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df[['age']],df.bought_insurance,test_size=0.1)

# %%
print(len(X_train),len(X_test))
# Out:
# 24 3

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
X_test
# Out:
#    age
# 0   22
# 8   62
# 4   46

# %%
y_predicted = model.predict(X_test)
y_predicted
# Out:
# array([0, 1, 1])

# %%
model.predict_proba(X_test)
# Out:
# array([[0.901071  , 0.098929  ],
#        [0.05393947, 0.94606053],
#        [0.30259019, 0.69740981]])

# %%
model.score(X_test,y_test)*100
# Out:
# 100.0
